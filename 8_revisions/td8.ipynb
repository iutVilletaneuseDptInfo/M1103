# %% [markdown]
# # TD 8 : Révisions

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# ### Question 1
#
# Définir la fonction `lastOcc` qui prend en paramètre une chaîne de caractères et un caractère, et retourne l'indice de la dernière occurrence du caractère dans la chaîne (-1 si le caractère n'est pas dans la chaîne).

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Quelle est la complexité dans le pire cas de la fonction `lastOcc` (en fonction du nombre de caractères de la chaîne) ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ### Question 3
#
# Définir une fonction de tests unitaires pour la fonction `lastOcc`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# On dispose d'un dictionnaire de prénoms. Les clés d'un tel dictionnaire sont des prénoms et les valeurs leur fréquence. La fréquence d'un prénom correspond au nombre d'enfants avec ce prénom qui sont nés cette année.

# %% [markdown]
# Pour tester les fonctions, on pourra utiliser le dictionnaire suivant.

# %%
prenoms = { 
    "GABRIEL" : 5419,
    "RAPHAËL" : 4591,
    "LÉO" : 4446,
    "LOUIS" : 4415,
    "EMMA" : 4369,
    "LUCAS" : 3979,
    "JADE" : 3977,
    "ADAM" : 3897,
    "LOUISE" : 3766,
    "ARTHUR" : 3755,
    "JULES" : 3698,
    "HUGO" : 3686,
    "ALICE" : 3313,
    "MAËL" : 3259,
    "LIAM" : 3149,
    "ETHAN" : 3147,
    "CHLOÉ" : 3126,
    "PAUL" : 2993,
    "NATHAN" : 2914,
    "LINA" : 2908 
}

# %% [markdown]
# ### Question 1

# %% [markdown]
# Définir la fonction `nombreEnfants` prenant un paramètre un dictionnaire de prénoms et retournant le nombre total d'enfants nés cette année.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2

# %% [markdown]
# Définir la fonction `prenomsSeuil` prenant en paramètre un dictionnaire de prénoms et une valeur. La fonction retourne un tableau contenant les prénoms dont la fréquence est supérieure ou égale à la valeur passée en paramètre.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 3

# %% [markdown]
# Définir la fonction `prenomsFrequents` prenant en paramètre un dictionnaire de prénoms et retournant un tableau contenant les prénoms les plus fréquents. Un prénom est dit fréquent si sa fréquence est supérieure d'au moins 10% à la fréquence moyenne d'un prénom.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 4

# %% [markdown]
# Définir la fonction `sommePremiereLettre` prenant en paramètre un dictionnaire de prénoms et retournant un dictionnaire dont les clés sont les premières lettres des prénoms et les valeurs la fréquence des prénoms commençant par cette lettre.
#
#
# **Remarque :** Le dictionnaire retourné ne contiendra aucune clé dont la valeur associée est 0.

# %%
############################## 
#   Saisir votre code ici.   #
##############################
